# %%
import pandas as pd
a1 = ['송중기', 92, 99, 69, 75]
a2 = ['김나현', 88, 91, 87, 83]
a3 = ['권보아', 72, 86, 71, 84]
a4 = ['박효신', 81, 78, 77, 91]
a5 = ['김범수', 88, 80, 94, 91]
a6 = ["noon", "mom", "dad", "level", "river"]
a7 = ["서울", "서울", "대구", "부산", "부산"]
a8 = ["대구", "서울", "부산", "서울", "부산"]
col1 = ["이름", "국어", "영어", "수학", "과학"]
col2 = ["서울", "대구", "부산"]
df1 = pd.DataFrame([a1, a2, a3, a4, a5], columns=col1)
df2 = df1.copy()
df3 = df1.copy()
df3["과학"] = df3["과학"].astype(str)
df4 = pd.DataFrame(df1["이름"])
df4["단어"] = a6
df5 = pd.DataFrame([[1,5,10], [5,1,5], [10,5,1]], index=col2, columns=col2)*1000
df6 = pd.DataFrame([a7,a8], index=["보내는곳", "받는곳"]).T
df6 = pd.concat([df1["이름"], df6], axis=1)

df1
# Out:
#     이름  국어  영어  수학  과학
# 0  송중기  92  99  69  75
# 1  김나현  88  91  87  83
# 2  권보아  72  86  71  84
# 3  박효신  81  78  77  91
# 4  김범수  88  80  94  91

# %%
df3
# Out:
#     이름  국어  영어  수학  과학
# 0  송중기  92  99  69  75
# 1  김나현  88  91  87  83
# 2  권보아  72  86  71  84
# 3  박효신  81  78  77  91
# 4  김범수  88  80  94  91

# %%
df3.info()
# 컬럼의 데이터 타입 확인 가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   국어      5 non-null      int64
#  2   영어      5 non-null      int64
#  3   수학      5 non-null      int64
#  4   과학      5 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
list(df3["과학"])
# 문자형
# Out:
# ['75', '83', '84', '91', '91']

# %%
list(df3["수학"])
# 숫자형
# Out:
# [69, 87, 71, 77, 94]

# %%
df3["과학"].astype("int")
# Out:
# 0    75
# 1    83
# 2    84
# 3    91
# 4    91
# Name: 과학, dtype: int32

# %%
df3["과학"].apply(int)
# apply 함수를 실행하기 위한 함수
# 판다스 함수가 아니고, 파이썬 기본 함수 및 사용자 함수를 실행하기 위함
# Out:
# 0    75
# 1    83
# 2    84
# 3    91
# 4    91
# Name: 과학, dtype: int64

# %%
df3["과학"] = df3["과학"].apply(int)
df3
# Out:
#     이름  국어  영어  수학  과학
# 0  송중기  92  99  69  75
# 1  김나현  88  91  87  83
# 2  권보아  72  86  71  84
# 3  박효신  81  78  77  91
# 4  김범수  88  80  94  91

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   국어      5 non-null      int64
#  2   영어      5 non-null      int64
#  3   수학      5 non-null      int64
#  4   과학      5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 328.0+ bytes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df4
# Out:
#     이름     단어
# 0  송중기   noon
# 1  김나현    mom
# 2  권보아    dad
# 3  박효신  level
# 4  김범수  river

# %%
df4["글자수"] = df4["단어"].apply(len)
df4

# apply(함수, axis=0 or 1)
# axis = 0 열
# axis = 1  행
# Out:
#     이름     단어  글자수
# 0  송중기   noon    4
# 1  김나현    mom    3
# 2  권보아    dad    3
# 3  박효신  level    5
# 4  김범수  river    5

# %%
df2
# Out:
#     이름  국어  영어  수학  과학
# 0  송중기  92  99  69  75
# 1  김나현  88  91  87  83
# 2  권보아  72  86  71  84
# 3  박효신  81  78  77  91
# 4  김범수  88  80  94  91

# %%
df2.mean()
# Out:
# C:\Users\toyuq\AppData\Local\Temp\ipykernel_9180\3587575296.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.mean()
# 국어    84.2
# 영어    86.8
# 수학    79.6
# 과학    84.8
# dtype: float64

# %%
df2.apply("mean")
# Out:
# C:\Users\toyuq\AppData\Local\Temp\ipykernel_9180\3650662919.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.apply("mean")
# 국어    84.2
# 영어    86.8
# 수학    79.6
# 과학    84.8
# dtype: float64

# %%
df2["평균"] = df2.apply("mean", axis=1)
df2
# Out:
# C:\Users\toyuq\AppData\Local\Temp\ipykernel_9180\3071429248.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2["평균"] = df2.apply("mean", axis=1)
#     이름  국어  영어  수학  과학     평균
# 0  송중기  92  99  69  75  83.75
# 1  김나현  88  91  87  83  87.25
# 2  권보아  72  86  71  84  78.25
# 3  박효신  81  78  77  91  81.75
# 4  김범수  88  80  94  91  88.25

# %%
def plus_one(x):
    return x+1

#사용자 정의함수

df1
# Out:
#     이름  국어  영어  수학  과학
# 0  송중기  92  99  69  75
# 1  김나현  88  91  87  83
# 2  권보아  72  86  71  84
# 3  박효신  81  78  77  91
# 4  김범수  88  80  94  91

# %%
df1["수학"].apply(plus_one)
# Out:
# 0    70
# 1    88
# 2    72
# 3    78
# 4    95
# Name: 수학, dtype: int64

# %%
df1["수학보정"] = df1["수학"].apply(lambda x:x+1)
df1 

#lambda는 1회용 짧은 함수
# Out:
#     이름  국어  영어  수학  과학  수학보정
# 0  송중기  92  99  69  75    70
# 1  김나현  88  91  87  83    88
# 2  권보아  72  86  71  84    72
# 3  박효신  81  78  77  91    78
# 4  김범수  88  80  94  91    95

# %%
df1["과학성적"] = df1["과학"].apply(lambda x:"A" if x > 90 else "B")
df1
# Out:
#     이름  국어  영어  수학  과학  수학보정 과학성적
# 0  송중기  92  99  69  75    70    B
# 1  김나현  88  91  87  83    88    B
# 2  권보아  72  86  71  84    72    B
# 3  박효신  81  78  77  91    78    A
# 4  김범수  88  80  94  91    95    A

# %%
df5
# Out:
#        서울    대구     부산
# 서울   1000  5000  10000
# 대구   5000  1000   5000
# 부산  10000  5000   1000

# %%
df6
# Out:
#     이름 보내는곳 받는곳
# 0  송중기   서울  대구
# 1  김나현   서울  서울
# 2  권보아   대구  부산
# 3  박효신   부산  서울
# 4  김범수   부산  부산

# %%
df5.loc["서울", "대구"]
# Out:
# 5000

# %%
df6["운임"] = df6.apply(lambda x: df5.loc[x["보내는곳"], x["받는곳"]], axis=1)
df6
# Out:
#     이름 보내는곳 받는곳     운임
# 0  송중기   서울  대구   5000
# 1  김나현   서울  서울   1000
# 2  권보아   대구  부산   5000
# 3  박효신   부산  서울  10000
# 4  김범수   부산  부산   1000

# %% [markdown]
# ![image.png](attachment:image.png)
